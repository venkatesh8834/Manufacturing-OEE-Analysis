# %%
import pandas as pd

# %%
import numpy as np

# %%
df=pd.read_csv('/content/production_realistic.csv')

# %%
df.head()
# Out:
#   Job_ID Machine_ID Operation_Type  Material_Used  Processing_Time  \
# 0   J001        M01       Grinding           3.17             91.2
# 1   J002        M01       Grinding           3.35             94.8
# 2   J003        M04       Additive           2.29             67.2
# 3   J004        M04       Grinding           1.76            127.2
# 4   J005        M01          Lathe           1.90             55.2
#
#    Energy_Consumption  Machine_Availability      Scheduled_Start  \
# 0               11.42                  76.8  2023-03-18 08:00:00
# 1                6.61                  67.2  2023-03-18 08:10:00
# 2               11.11                  73.6  2023-03-18 08:20:00
# 3               12.50                  76.0  2023-03-18 08:30:00
# 4                8.13                  70.4  2023-03-18 08:40:00
#
#          Scheduled_End         Actual_Start           Actual_End Job_Status  \
# 0  2023-03-18 09:16:00  2023-03-18 08:05:00  2023-03-18 09:21:00  Completed
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Job_ID                 1000 non-null   object
#  1   Machine_ID             1000 non-null   object
#  2   Operation_Type         1000 non-null   object
#  3   Material_Used          1000 non-null   float64
#  4   Processing_Time        1000 non-null   float64
#  5   Energy_Consumption     1000 non-null   float64
#  6   Machine_Availability   1000 non-null   float64
#  7   Scheduled_Start        1000 non-null   object
#  8   Scheduled_End          1000 non-null   object
#  9   Actual_Start           871 non-null    object
#  10  Actual_End             871 non-null    object
#  11  Job_Status             1000 non-null   object
#  12  Optimization_Category  1000 non-null   object
#  13  Planned_Time           1000 non-null   float64
# ...

# %%
df.describe()
# Out:
#        Material_Used  Processing_Time  Energy_Consumption  \
# count    1000.000000      1000.000000         1000.000000
# mean        3.026480        77.221200            8.521340
# std         1.148139        31.632445            3.669941
# min         1.010000        20.000000            2.010000
# 25%         2.040000        51.600000            5.397500
# 50%         3.080000        78.000000            8.560000
# 75%         4.042500       102.000000           11.672500
# max         5.000000       144.000000           14.980000
#
#        Machine_Availability  Planned_Time  Actual_Run_Time  Downtime
# count           1000.000000    1000.00000       871.000000     871.0
# mean              81.847400      71.38400        71.315729       0.0
# std               10.371086      28.48438        28.511747       0.0
# min               64.000000      20.00000        20.000000       0.0
# 25%               72.800000      48.00000        47.000000       0.0
# ...

# %%
df.drop_duplicates()
# Out:
#     Job_ID Machine_ID Operation_Type  Material_Used  Processing_Time  \
# 0     J001        M01       Grinding           3.17             91.2
# 1     J002        M01       Grinding           3.35             94.8
# 2     J003        M04       Additive           2.29             67.2
# 3     J004        M04       Grinding           1.76            127.2
# 4     J005        M01          Lathe           1.90             55.2
# ..     ...        ...            ...            ...              ...
# 995   J996        M02        Milling           4.86             50.0
# 996   J997        M05          Lathe           2.72             60.0
# 997   J998        M03          Lathe           1.31            102.0
# 998   J999        M02          Lathe           2.40             75.0
# 999  J1000        M05       Additive           1.32            111.0
#
#      Energy_Consumption  Machine_Availability      Scheduled_Start  \
# 0                 11.42                  76.8  2023-03-18 08:00:00
# ...

# %%
df=df.replace(r'^\s*$',pd.NA,regex=True)

# %%
df=df.fillna("null")

# %%
df.head()
# Out:
#    Unnamed: 0 Job_ID Machine_ID Operation_Type  Material_Used  \
# 0           0   J001        M01       Grinding           3.17
# 1           1   J002        M01       Grinding           3.35
# 2           2   J003        M04       Additive           2.29
# 3           3   J004        M04       Grinding           1.76
# 4           4   J005        M01          Lathe           1.90
#
#    Processing_Time  Energy_Consumption  Machine_Availability  \
# 0             91.2               11.42                  76.8
# 1             94.8                6.61                  67.2
# 2             67.2               11.11                  73.6
# 3            127.2               12.50                  76.0
# 4             55.2                8.13                  70.4
#
#       Scheduled_Start       Scheduled_End         Actual_Start  \
# 0 2023-03-18 08:00:00 2023-03-18 09:16:00  2023-03-18 08:05:00
# 1 2023-03-18 08:10:00 2023-03-18 09:29:00  2023-03-18 08:20:00
# ...

# %%
date_cols=['Scheduled_Start','Scheduled_End','Actual_Start','Actual_End']

# %%
df[date_cols]=df[date_cols].apply(pd.to_datetime,errors='coerce')

# %%
df.to_csv("production_res.csv",index='false')

# %%
df=pd.read_csv('/content/production_re.csv')

# %%
df.head()
# Out:
#    Unnamed: 0 Job_ID Machine_ID Operation_Type  Material_Used  \
# 0           0   J001        M01       Grinding           3.17
# 1           1   J002        M01       Grinding           3.35
# 2           2   J003        M04       Additive           2.29
# 3           3   J004        M04       Grinding           1.76
# 4           4   J005        M01          Lathe           1.90
#
#    Processing_Time  Energy_Consumption  Machine_Availability  \
# 0             91.2               11.42                  76.8
# 1             94.8                6.61                  67.2
# 2             67.2               11.11                  73.6
# 3            127.2               12.50                  76.0
# 4             55.2                8.13                  70.4
#
#        Scheduled_Start        Scheduled_End         Actual_Start  \
# 0  2023-03-18 08:00:00  2023-03-18 09:16:00  2023-03-18 08:05:00
# 1  2023-03-18 08:10:00  2023-03-18 09:29:00  2023-03-18 08:20:00
# ...

# %%
df1=pd.read_csv('/content/production_res.csv')

# %%
df1.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0 Job_ID Machine_ID Operation_Type  Material_Used  \
# 0             0           0   J001        M01       Grinding           3.17
# 1             1           1   J002        M01       Grinding           3.35
# 2             2           2   J003        M04       Additive           2.29
# 3             3           3   J004        M04       Grinding           1.76
# 4             4           4   J005        M01          Lathe           1.90
#
#    Processing_Time  Energy_Consumption  Machine_Availability  \
# 0             91.2               11.42                  76.8
# 1             94.8                6.61                  67.2
# 2             67.2               11.11                  73.6
# 3            127.2               12.50                  76.0
# 4             55.2                8.13                  70.4
#
#        Scheduled_Start        Scheduled_End         Actual_Start  \
# 0  2023-03-18 08:00:00  2023-03-18 09:16:00  2023-03-18 08:05:00
# ...
